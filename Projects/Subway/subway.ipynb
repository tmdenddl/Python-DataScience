# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('data/subway.csv')

df
# Out:
#     line       station     in    out
# 0    중앙선            지평     37     28
# 1    중앙선            용문   2064   2103
# 2    중앙선            원덕    375    357
# 3    중앙선            양평   4338   4378
# 4    중앙선            오빈    321    321
# 5    중앙선            아신    589    595
# 6    중앙선            국수    908    844
# 7    중앙선            신원    213    199
# 8    중앙선            양수   1804   1778
# 9    중앙선           운길산    668    594
# 10   중앙선            팔당    747    726
# 11   중앙선            도심   2907   2323
# 12   중앙선            덕소   6745   6726
# 13   중앙선            양정    912    741
# 14   중앙선            도농  10106   8899
# 15   중앙선            구리  15589  15783
# 16   중앙선            양원   1705   1744
# 17   중앙선            망우   8154   8140
# 18   중앙선   상봉(시외버스터미널)   6160   5924
# 19   중앙선            중랑   6082   5828
# 20   중앙선            회기  28113  27527
# 21   장항선      신창(순천향대)   1134   1103
# 22   장항선          온양온천   4629   4677
# 23   장항선            배방   1018    968
# ...

# %%
df['in']
# Out:
# 0         37
# 1       2064
# 2        375
# 3       4338
# 4        321
# 5        589
# 6        908
# 7        213
# 8       1804
# 9        668
# 10       747
# 11      2907
# 12      6745
# 13       912
# 14     10106
# 15     15589
# 16      1705
# 17      8154
# 18      6160
# 19      6082
# 20     28113
# 21      1134
# 22      4629
# 23      1018
# 24      2409
# 25      2136
# 26      1448
# 27     15991
# 28     10840
# 29      8767
#        ...
# 561    70000
# 562    66031
# 563    11152
# 564    27402
# 565    89897
# 566    19971
# 567    43646
# 568    27574
# 569    43410
# 570    34422
# 571    20842
# 572    10091
# 573    20651
# 574    16263
# 575    16146
# 576    17563
# 577    14150
# 578    26606
# 579    55813
# 580    30269
# 581     8749
# 582    27401
# 583    22536
# 584    17086
# 585    14585
# 586    31245
# 587    38099
# 588    52310
# 589    29150
# 590    58391
# Name: in, Length: 591, dtype: int64

# %%
sns.kdeplot(df['in'])
