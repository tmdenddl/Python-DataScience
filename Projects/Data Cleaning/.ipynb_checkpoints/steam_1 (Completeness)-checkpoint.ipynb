# %%
import pandas as pd

df = pd.read_csv('data/steam_1.csv')

df
# Out:
#                                          Name  Hours
# 0                  The Elder Scrolls V Skyrim  273.0
# 1                                   Fallout 4   87.0
# 2                                       Spore   14.9
# 3                           Fallout New Vegas   12.1
# 4                               Left 4 Dead 2    8.9
# 5                                    HuniePop    8.5
# 6                               Path of Exile    8.1
# 7                                 Poly Bridge    7.5
# 8                                 Left 4 Dead    3.3
# 9                             Team Fortress 2    2.8
# 10                                Tomb Raider    2.5
# 11                            The Banner Saga    2.0
# 12                       Dead Island Epidemic    1.4
# 13                          BioShock Infinite    1.3
# 14      Dragon Age Origins - Ultimate Edition    1.3
# 15       Fallout 3 - Game of the Year Edition    0.8
# 16         SEGA Genesis & Mega Drive Classics    0.8
# ...

# %%
df.isnull()
# Out:
#         Name  Hours
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# 5      False  False
# 6      False  False
# 7      False  False
# 8      False  False
# 9      False  False
# 10     False  False
# 11     False  False
# 12     False  False
# 13     False  False
# 14     False  False
# 15     False  False
# 16     False  False
# 17     False  False
# 18     False  False
# 19     False  False
# 20     False  False
# 21     False  False
# 22     False  False
# 23     False  False
# 24     False  False
# 25     False  False
# 26     False  False
# 27     False  False
# 28     False  False
# 29     False  False
# ...      ...    ...
# 20196  False  False
# 20197  False  False
# 20198  False  False
# 20199  False  False
# 20200  False  False
# 20201  False  False
# 20202  False  False
# 20203  False  False
# 20204  False  False
# 20205  False  False
# 20206  False  False
# 20207  False  False
# 20208  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Name      0
# Hours    10
# dtype: int64

# %%
df.dropna()
