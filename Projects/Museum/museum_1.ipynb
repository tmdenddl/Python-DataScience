# %%
import pandas as pd

df = pd.read_csv('data/museum_1.csv')

df
# Out:
#                  시설명  어른관람료       운영기관전화번호
# 0         필암서원 유물전시관    500   061-390-7224
# 1            원주역사박물관      0   033-737-4371
# 2            뮤지엄산미술관  15000   033-730-9000
# 3          오랜미래신화미술관      0   033-746-5256
# 4        연세대학교 원주박물관      0   033-760-2731
# 5            뮤지엄산박물관  15000   033-730-9000
# 6        뮤지엄산(청조갤러리)  15000   033-730-9000
# 7         치악산 고판화박물관   5000   033-761-7885
# 8            남원향토박물관      0   063-620-5797
# 9              청도박물관      0   054-370-2282
# 10             합천박물관      0   055-930-4882
# 11          합천한의학박물관   2000   055-934-0601
# 12          해인사성보박물관   2000   055-934-3150
# 13             신풍미술관   2000   054-653-9329
# 14             예천박물관      0   054-650-8311
# 15             신풍미술관   2000   054-653-9329
# 16             예천박물관      0   054-650-8311
# 17           인천개항박물관    500   032-760-7508
# 18            짜장면박물관    500   032-773-9812
# 19             영종역사관   1000   032-760-6300
# 20          중구생활사전시관   1000   032-766-2202
# ...

# %%
uni = df[df['시설명'].str.contains('대학')]
uni
# Out:
#                     시설명  어른관람료       운영기관전화번호  분류
# 4           연세대학교 원주박물관      0   033-760-2731  일반
# 26      신구대학교식물원 갤러리 우촌   7000   031-724-1625  일반
# 28           신구대학 우촌박물관      0   031-740-1258  일반
# 65             경성대학교박물관      0   051-663-5381  일반
# 66             부경대학교박물관      0   051-629-6771  일반
# 68             경성대학교미술관      0   051-663-5361  일반
# 82          덕성여자대학교 박물관      0    02-901-8131  일반
# 96            제주대학교?박물관      0   064-754-2242  일반
# 147           경북대학교 박물관      0   053-950-6537  일반
# 148       대구보건대학교 인당박물관      0   053-320-1857  일반
# 149           경북대학교 미술관      0   053-950-7968  일반
# 151         계명대학교 행소박물관      0   053-580-6992  일반
# 199            전북대학교박물관      0   063-270-3488  일반
# 200            전주대학교박물관      0   063-220-2159  일반
# 201            군산대학교박물관      0   063-469-4191  일반
# 202            원광대학교박물관      0   063-850-5482  일반
# 244            건국대학교박물관      0    02-450-3880  일반
# 245            세종대학교박물관      0   02-3408-3277  일반
# ...

# %%
df['분류'] = '일반'
df
# Out:
#                  시설명  어른관람료       운영기관전화번호  분류
# 0         필암서원 유물전시관    500   061-390-7224  일반
# 1            원주역사박물관      0   033-737-4371  일반
# 2            뮤지엄산미술관  15000   033-730-9000  일반
# 3          오랜미래신화미술관      0   033-746-5256  일반
# 4        연세대학교 원주박물관      0   033-760-2731  일반
# 5            뮤지엄산박물관  15000   033-730-9000  일반
# 6        뮤지엄산(청조갤러리)  15000   033-730-9000  일반
# 7         치악산 고판화박물관   5000   033-761-7885  일반
# 8            남원향토박물관      0   063-620-5797  일반
# 9              청도박물관      0   054-370-2282  일반
# 10             합천박물관      0   055-930-4882  일반
# 11          합천한의학박물관   2000   055-934-0601  일반
# 12          해인사성보박물관   2000   055-934-3150  일반
# 13             신풍미술관   2000   054-653-9329  일반
# 14             예천박물관      0   054-650-8311  일반
# 15             신풍미술관   2000   054-653-9329  일반
# 16             예천박물관      0   054-650-8311  일반
# 17           인천개항박물관    500   032-760-7508  일반
# 18            짜장면박물관    500   032-773-9812  일반
# ...

# %%
uni_bool = df['시설명'].str.contains('대학')
uni_bool
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883     True
# 884    False
# 885     True
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# 893    False
# 894    False
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# Name: 시설명, Length: 900, dtype: bool

# %%
df.loc[uni_bool, '분류'] = '대학'
df
# Out:
#                  시설명  어른관람료       운영기관전화번호  분류
# 0         필암서원 유물전시관    500   061-390-7224  일반
# 1            원주역사박물관      0   033-737-4371  일반
# 2            뮤지엄산미술관  15000   033-730-9000  일반
# 3          오랜미래신화미술관      0   033-746-5256  일반
# 4        연세대학교 원주박물관      0   033-760-2731  대학
# 5            뮤지엄산박물관  15000   033-730-9000  일반
# 6        뮤지엄산(청조갤러리)  15000   033-730-9000  일반
# 7         치악산 고판화박물관   5000   033-761-7885  일반
# 8            남원향토박물관      0   063-620-5797  일반
# 9              청도박물관      0   054-370-2282  일반
# 10             합천박물관      0   055-930-4882  일반
# 11          합천한의학박물관   2000   055-934-0601  일반
# 12          해인사성보박물관   2000   055-934-3150  일반
# 13             신풍미술관   2000   054-653-9329  일반
# 14             예천박물관      0   054-650-8311  일반
# 15             신풍미술관   2000   054-653-9329  일반
# 16             예천박물관      0   054-650-8311  일반
# 17           인천개항박물관    500   032-760-7508  일반
# 18            짜장면박물관    500   032-773-9812  일반
# ...
